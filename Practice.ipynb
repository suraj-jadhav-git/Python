# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj-jadhav-git/Python/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Python Program to Print Hello world!

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# 2. Python Program to Add Two Numbers

# %%
a = int(input())
b = int(input())
print('sum =',a+b)
# Out:
# 4
# 5
# sum = 9

# %% [markdown]
# 3. Python Program to Find the Square Root

# %%
a = int(input())
print('Square root of', a, 'is',int(a**0.5))
# Out:
# 100
# Square root of 100 is 10

# %% [markdown]
# 4. Python Program to Calculate the Area of a Triangle

# %%
base = float(input('enter base of triange'))
height = float(input('enter height of traingle'))
area = 0.5 * base * height
print('Area of Traingle is', area)
# Out:
# enter base of triange40.55
# enter height of traingle90
# Area of Traingle is 1824.7499999999998

# %% [markdown]
# 5. Python Program to Solve Quadratic Equation

# %%
a =float(input('enter value of a '))
b = float(input('enter value of b '))
c = float(input('enter value of c '))

x= (-(b)+(((b)**2)-(4*(a)*(c)))**0.5)/2*(a)
y= (-(b)-(((b)**2)-(4*(a)*(c)))**0.5)/2*(a)


print (x,y)
# Out:
# enter value of a 1
# enter value of b -5
# enter value of c 6
# 3.0 2.0
